# %%
import numpy as np

# %%
def f(x):
    return 3* x ** 2 - 4*x + 5

# %%
x = np.arange(-5, 6, 0.5)
x
# Out:
# array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#         0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,  5.5])

# %%
y = f(x)
y
# Out:
# array([100.  ,  83.75,  69.  ,  55.75,  44.  ,  33.75,  25.  ,  17.75,
#         12.  ,   7.75,   5.  ,   3.75,   4.  ,   5.75,   9.  ,  13.75,
#         20.  ,  27.75,  37.  ,  47.75,  60.  ,  73.75])

# %%
import matplotlib.pyplot as plt

plt.plot(x,y)
